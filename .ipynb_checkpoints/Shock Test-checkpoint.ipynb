# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
address = r"C:\Users\Deniz\Programming\OSI Shock Test\shock_table_input_data_simplified.csv"
dataset = pd.read_csv(address)

# %%
dataset.shape
# Out:
# (164, 19)

# %%
dataset.head(2)
# Out:
#             Project Console  Acceleration (G)  Blow Vertical Direction (0/1)  \
# 0  170582 Chile - Ship Rack             13.32                              1
# 1  170582 Chile - Ship Rack             24.63                              1
#
#    Blow Side Direction (0/1)  Blow Front Direction (0/1)  \
# 0                          0                           0
# 1                          0                           0
#
#    Sensor X-Axis, Side Direction (0/1)  \
# 0                                    1
# 1                                    0
#
#    Sensor Y-Axis, Vertical Direction (0/1)  \
# 0                                        0
# 1                                        1
#
#    Sensor Z-Axis, Front Direction (0/1)  Console Mass (kg) Fixture Mass (kg)  \
# 0                                     0             185.46            778.64
# 1                                     0             185.46            778.64
#
#    Hardware Mass (kg) Anvil Table Mass (kg)  Hammer Height (m)  \
# 0             1385.47               2349.57              0.762
# 1             1385.47               2349.57              0.762
#
#    Table Travel (m)  CG Height (m)  Number of Bottom Isolators  \
# 0            0.0762           0.98                           6
# 1            0.0762           0.98                           6
#
#    Number of Side Isolators  Isolator Damping Coefficient  \
# 0                         2                          0.05
# 1                         2                          0.05
#
#    Isolator Stiffness (N/mm)
# 0                     122.59
# 1                     122.59

# %%
dataset.describe()
# Out:
#        Acceleration (G)  Blow Vertical Direction (0/1)  \
# count        164.000000                     164.000000
# mean         148.446280                       0.475610
# std          191.790122                       0.500934
# min            6.570000                       0.000000
# 25%           42.000000                       0.000000
# 50%          100.000000                       0.000000
# 75%          182.300000                       1.000000
# max         1438.340000                       1.000000
#
#        Blow Side Direction (0/1)  Blow Front Direction (0/1)  \
# count                 164.000000                  164.000000
# mean                    0.310976                    0.213415
# std                     0.464311                    0.410973
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    0.000000
# 75%                     1.000000                    0.000000
# max                     1.000000                    1.000000
#
#        Sensor X-Axis, Side Direction (0/1)  \
# count                           164.000000
# mean                              0.274390
# std                               0.447573
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               1.000000
# max                               1.000000
#
#        Sensor Y-Axis, Vertical Direction (0/1)  \
# count                               164.000000
# mean                                  0.347561
# std                                   0.477654
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   1.000000
# max                                   1.000000
#
#        Sensor Z-Axis, Front Direction (0/1)  Console Mass (kg)  \
# count                            164.000000         164.000000
# mean                               0.378049         226.962378
# std                                0.486385         114.809644
# min                                0.000000          33.430000
# 25%                                0.000000         185.460000
# 50%                                0.000000         230.000000
# 75%                                1.000000         254.540000
# max                                1.000000         400.000000
#
#        Hardware Mass (kg)  Hammer Height (m)  Table Travel (m)  CG Height (m)  \
# count          164.000000         164.000000        164.000000     164.000000
# mean           726.974939           1.053354          0.063235       1.294839
# std            491.151712           0.477370          0.018397       0.247747
# min            110.380000           0.076200          0.038100       0.838200
# 25%            163.700000           0.690000          0.038100       1.150000
# 50%            946.290000           0.914400          0.076200       1.320800
# 75%           1074.395000           1.676400          0.076200       1.520000
# max           1469.110000           1.680000          0.080000       1.630000
#
#        Number of Bottom Isolators  Number of Side Isolators  \
# count                  164.000000                164.000000
# mean                     6.731707                  1.256098
# std                      2.090286                  1.175527
# min                      0.000000                  0.000000
# 25%                      6.000000                  0.000000
# 50%                      8.000000                  2.000000
# 75%                      8.000000                  2.000000
# max                      8.000000                  4.000000
#
#        Isolator Damping Coefficient  Isolator Stiffness (N/mm)
# count                  1.640000e+02                 164.000000
# mean                   5.000000e-02                 145.756524
# std                    6.960146e-18                  96.170624
# min                    5.000000e-02                  40.470000
# 25%                    5.000000e-02                  93.000000
# 50%                    5.000000e-02                 122.590000
# 75%                    5.000000e-02                 122.590000
# max                    5.000000e-02                 316.000000

# %%
dataset.isnull().any()
# Out:
# Project Console                            False
# Acceleration (G)                           False
# Blow Vertical Direction (0/1)              False
# Blow Side Direction (0/1)                  False
# Blow Front Direction (0/1)                 False
# Sensor X-Axis, Side Direction (0/1)        False
# Sensor Y-Axis, Vertical Direction (0/1)    False
# Sensor Z-Axis, Front Direction (0/1)       False
# Console Mass (kg)                          False
# Fixture Mass (kg)                          False
# Hardware Mass (kg)                         False
# Anvil Table Mass (kg)                      False
# Hammer Height (m)                          False
# Table Travel (m)                           False
# CG Height (m)                              False
# Number of Bottom Isolators                 False
# Number of Side Isolators                   False
# Isolator Damping Coefficient               False
# Isolator Stiffness (N/mm)                  False
# dtype: bool

# %%
X = dataset.iloc[:, 2:].values  # Column index 2 to the end
y = dataset.iloc[:, 1].values  # Column index 1 (acceleration)

# %%
plt.figure(figsize=(15,10))
sns.histplot(y)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
plt.figure(figsize=(15,10))
sns.histplot(y, log_scale=True)
# Out:
# <AxesSubplot:ylabel='Count'>
